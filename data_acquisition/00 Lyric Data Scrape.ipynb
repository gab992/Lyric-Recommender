# %%
import data_acquisition_functions as dat_func

# %%
# Get list of artists and albums in the pitchfork top 200 albums of the 2010s list

artists, albums = dat_func.get_artist_album_lists()

# %%
# Get a list of urls to the genius.com song lyrics for the songs in the pitchfork list of best 200 albums of the 2010s
page_links = dat_func.get_links(artists, albums)
# Out:
# So It Goes
# Go Tell Fire to the Mountain
# Everything’s Fine
# Genre-Specific Xperience
# Vexovoid
# Full Communism
# The Monitor
# Hellboy
# Cut 4 Me
# 50 Words for Snow
# For Those of You Who Have Never (and Also Those Who Have)
# The Weight of These Wings
# Daytona
# Beyondless
# Mono No Aware
# Lala Belu
# Clean
# American Drift
# Trans Day of Revenge
# LEGACY! LEGACY!
# The Bones of What You Believe
# Black Up
# Silence Yourself
# All American Made
# I’m New Here
# Devotion
# Are We There
# Small Town Heroes
# Where We Come From
# Veteran
# Compro
# After Laughter
# The Magic Place
# DSU
# The Pinkprint
# Everybody Works
# Painted Shut
# Dreamchasers 2
# Metamodern Sounds in Country Music
# I like it when you sleep…
# Room 25
# Foundations of Burden
# Treats
# A Brief Inquiry Into Online Relationships
# The Voyager
# Savage Mode
# Under the Skin OST
# Purple Mountains
# AM
# The Fame Monster
# Playboi Carti
# 2
# Space Is Only Noise
# High Violet
# Compilation
# Finally Rich
# ...

# %%
# Get json files for each song, also keep track of list of failed links
failed = []
for link in page_links:
    try:
        dat_func.get_json(link)
        time.sleep(np.random.randint(3,7))
    except:
        failed.append(link)

# %%
len(page_links)
# Out:
# 2285

# %%
len(failed)
# Out:
# 27

# %% [markdown]
# **This section adds a list of links I manually created from songs that were missed by the initial data scrape.
# If rerunning the web scraping, this list may no longer be accurate**

# %%
corrections = [
    'https://genius.com/Kendrick-lamar-sherane-aka-master-splinters-daughter-lyrics',
    'https://genius.com/Kendrick-lamar-bitch-dont-kill-my-vibe-lyrics',
    'https://genius.com/Kendrick-lamar-backseat-freestyle-lyrics',
    'https://genius.com/Kendrick-lamar-the-art-of-peer-pressure-lyrics',
    'https://genius.com/Kendrick-lamar-money-trees-lyrics',
    'https://genius.com/Kendrick-lamar-poetic-justice-lyrics',
    'https://genius.com/Kendrick-lamar-good-kid-lyrics',
    'https://genius.com/Kendrick-lamar-maad-city-lyrics',
    'https://genius.com/Kendrick-lamar-swimming-pools-drank-lyrics',
    'https://genius.com/Kendrick-lamar-sing-about-me-im-dying-of-thirst-lyrics',
    'https://genius.com/Kendrick-lamar-real-lyrics',
    'https://genius.com/Kendrick-lamar-compton-lyrics',
    'https://genius.com/Lana-del-rey-norman-fucking-rockwell-lyrics',
    'https://genius.com/Lana-del-rey-mariners-apartment-complex-lyrics',
    'https://genius.com/Lana-del-rey-venice-bitch-lyrics',
    'https://genius.com/Lana-del-rey-fuck-it-i-love-you-lyrics',
    'https://genius.com/Lana-del-rey-doin-time-lyrics',
    'https://genius.com/Lana-del-rey-love-song-lyrics',
    'https://genius.com/Lana-del-rey-cinnamon-girl-lyrics',
    'https://genius.com/Lana-del-rey-how-to-disappear-lyrics',
    'https://genius.com/Lana-del-rey-california-lyrics',
    'https://genius.com/Lana-del-rey-the-next-best-american-record-lyrics',
    'https://genius.com/Lana-del-rey-the-greatest-lyrics',
    'https://genius.com/Lana-del-rey-bartender-lyrics',
    'https://genius.com/Lana-del-rey-happiness-is-a-butterfly-lyrics'
    'https://genius.com/Ariana-grande-successful-lyrics',
    'https://genius.com/Ariana-grande-everytime-lyrics',
    'https://genius.com/Ariana-grande-breathin-lyrics',
    'https://genius.com/Ariana-grande-no-tears-left-to-cry-lyrics',
    'https://genius.com/Ariana-grande-borderline-lyrics',
    'https://genius.com/Ariana-grande-better-off-lyrics',
    'https://genius.com/Ariana-grande-goodnight-n-go-lyrics',
    'https://genius.com/Ariana-grande-pete-davidson-lyrics',
    'https://genius.com/Ariana-grande-get-well-soon-lyrics',
    'https://genius.com/Kendrick-lamar-wesleys-theory-lyrics',
    'https://genius.com/Kendrick-lamar-for-free-interlude-lyrics',
    'https://genius.com/Kendrick-lamar-king-kunta-lyrics',
    'https://genius.com/Kendrick-lamar-institutionalized-lyrics',
    'https://genius.com/Kendrick-lamar-these-walls-lyrics',
    'https://genius.com/Kendrick-lamar-u-lyrics',
    'https://genius.com/Kendrick-lamar-alright-lyrics',
    'https://genius.com/Kendrick-lamar-for-sale-interlude-lyrics',
    'https://genius.com/Kendrick-lamar-momma-lyrics',
    'https://genius.com/Kendrick-lamar-hood-politics-lyrics',
    'https://genius.com/Kendrick-lamar-how-much-a-dollar-cost-lyrics',
    'https://genius.com/Kendrick-lamar-complexion-a-zulu-love-lyrics',
    'https://genius.com/Kendrick-lamar-the-blacker-the-berry-lyrics',
    'https://genius.com/Kendrick-lamar-you-aint-gotta-lie-momma-said-lyrics',
    'https://genius.com/Kendrick-lamar-i-album-version-lyrics',
    'https://genius.com/Kendrick-lamar-mortal-man-lyrics',
    'https://genius.com/Kendrick-lamar-blood-lyrics',
    'https://genius.com/Kendrick-lamar-dna-lyrics',
    'https://genius.com/Kendrick-lamar-yah-lyrics',
    'https://genius.com/Kendrick-lamar-element-lyrics',
    'https://genius.com/Kendrick-lamar-feel-lyrics',
    'https://genius.com/Kendrick-lamar-loyalty-lyrics',
    'https://genius.com/Kendrick-lamar-pride-lyrics',
    'https://genius.com/Kendrick-lamar-humble-lyrics',
    'https://genius.com/Kendrick-lamar-lust-lyrics',
    'https://genius.com/Kendrick-lamar-love-lyrics',
    'https://genius.com/Kendrick-lamar-xxx-lyrics',
    'https://genius.com/Kendrick-lamar-fear-lyrics',
    'https://genius.com/Kendrick-lamar-god-lyrics',
    'https://genius.com/Kendrick-lamar-duckworth-lyrics',
    'https://genius.com/Taylor-swift-state-of-grace-lyrics',
    'https://genius.com/Taylor-swift-red-lyrics',
    'https://genius.com/Taylor-swift-treacherous-lyrics',
    'https://genius.com/Taylor-swift-i-knew-you-were-trouble-lyrics',
    'https://genius.com/Taylor-swift-all-too-well-lyrics',
    'https://genius.com/Taylor-swift-22-lyrics',
    'https://genius.com/Taylor-swift-i-almost-do-lyrics',
    'https://genius.com/Taylor-swift-we-are-never-ever-getting-back-together-lyrics',
    'https://genius.com/Taylor-swift-stay-stay-stay-lyrics',
    'https://genius.com/Taylor-swift-the-last-time-lyrics',
    'https://genius.com/Taylor-swift-holy-ground-lyrics',
    'https://genius.com/Taylor-swift-sad-beautiful-tragic-lyrics',
    'https://genius.com/Taylor-swift-the-lucky-one-lyrics',
    'https://genius.com/Taylor-swift-everything-has-changed-lyrics',
    'https://genius.com/Taylor-swift-starlight-lyrics',
    'https://genius.com/Taylor-swift-begin-again-lyrics'
]

# %%
for track in corrections:
    try:
        get_json(track)
    except:
        print(track)
